# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikgandhi/Computer-Vision/blob/main/Point_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/gdrive')
src = cv.imread('/content/gdrive/MyDrive/points.PNG')
plt.imshow(cv.cvtColor(src, cv.COLOR_BGR2RGB))
# Out:
# Mounted at /content/gdrive

# %%
src = cv.GaussianBlur(src, (3, 3), 0)
src_gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
kernel_size = 3
depth = cv.CV_16S
dst = cv.Laplacian(src_gray, depth, ksize=kernel_size)
plt.imshow(dst)
abs_dst = cv.convertScaleAbs(dst)
plt.imshow(abs_dst)
